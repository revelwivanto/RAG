# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("laptop_listings_all_cleaned_web_enriched_deduplicated.csv")
df.groupby("brand").size().plot(kind="bar")
# Out:
# <Axes: xlabel='brand'>
